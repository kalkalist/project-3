# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('main_task_new.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_id      40000 non-null  object
#  1   city               40000 non-null  object
#  2   Cuisine Style      30717 non-null  object
#  3   Ranking            40000 non-null  int64
#  4   Rating             40000 non-null  float64
#  5   Price              26114 non-null  object
#  6   Number of Reviews  37457 non-null  float64
#  7   Reviews            40000 non-null  object
#  8   URL_TA             40000 non-null  object
#  9   ID_TA              40000 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 3.1+ MB

# %%
def fill_population(s):
    if s == "Paris":
        return 2.148
    elif s == "Stockholm":
        return 0.976
    elif s == "London":
        return 8.982
    elif s == "Berlin":
        return 3.769
    elif s == "Munich":
        return 1.472
    elif s == "Oporto":
        return 0.214
    elif s == "Milan":
        return 1.352
    elif s == "Bratislava":
        return 0.424
    elif s == "Vienna":
        return 1.897
    elif s == "Rome":
        return 2.873
    elif s == "Barcelona":
        return 5.575
    elif s == "Madrid":
        return 6.642
    elif s == "Dublin":
        return 1.388
    elif s == "Brussels":
        return 0.174
    elif s == "Zurich":
        return 0.403
    elif s == "Warsaw":
        return 1.708
    elif s == "Budapest":
        return 1.752
    elif s == "Copenhagen":
        return 0.603
    elif s == "Amsterdam":
        return 0.823
    elif s == "Lyon":
        return 0.513
    elif s == "Hamburg":
        return 1.845
    elif s == "Lisbon":
        return 0.505
    elif s == "Prague":
        return 1.309
    elif s == "Oslo":
        return 0.681
    elif s == "Helsinki":
        return 0.632
    elif s == "Edinburgh":
        return 0.482
    elif s == "Geneva":
        return 0.5
    elif s == "Ljubljana":
        return 0.28
    elif s == "Athens":
        return 0.664
    elif s == "Luxembourg":
        return 0.614
    elif s == "Krakow":
        return 0.763
df['city_population'] = df['city'].apply(fill_population)
df['city_population']
# Out:
# 0        2.148
# 1        0.976
# 2        8.982
# 3        3.769
# 4        1.472
#          ...
# 39995    1.352
# 39996    2.148
# 39997    0.976
# 39998    1.708
# 39999    1.352
# Name: city_population, Length: 40000, dtype: float64

# %%
df.sample(5)
# Out:
#       Restaurant_id       city  \
# 6741         id_489  Edinburgh
# 14311         id_13       Lyon
# 1491        id_1341   Brussels
# 7970         id_494  Edinburgh
# 34623        id_905     Dublin
#
#                                            Cuisine Style  Ranking  Rating  \
# 6741         ['Chinese', 'Asian', 'Vegetarian Friendly']      490     4.5
# 14311                             ['French', 'European']       14     4.5
# 1491                                         ['Italian']     1342     4.0
# 7970   ['Italian', 'Cafe', 'British', 'International'...      495     4.5
# 34623              ['Bar', 'Pub', 'Vegetarian Friendly']      907     4.5
#
#           Price  Number of Reviews  \
# 6741   $$ - $$$               93.0
# 14311  $$ - $$$              389.0
# 1491   $$ - $$$               50.0
# 7970   $$ - $$$              193.0
# 34623  $$ - $$$               22.0
#
#                                                  Reviews  \
# ...

# %%
df['Price'] = df['Price'].apply(lambda x: 1 if x == '$' else 2 if x == '$$ - $$$' else 3 if x == '$$$$' else x)
df
# Out:
#       Restaurant_id       city  \
# 0           id_5569      Paris
# 1           id_1535  Stockholm
# 2            id_352     London
# 3           id_3456     Berlin
# 4            id_615     Munich
# ...             ...        ...
# 39995        id_499      Milan
# 39996       id_6340      Paris
# 39997       id_1649  Stockholm
# 39998        id_640     Warsaw
# 39999       id_4824      Milan
#
#                                            Cuisine Style  Ranking  Rating  \
# 0                ['European', 'French', 'International']     5570     3.5
# 1                                                    NaN     1537     4.0
# 2      ['Japanese', 'Sushi', 'Asian', 'Grill', 'Veget...      353     4.5
# 3                                                    NaN     3458     5.0
# 4      ['German', 'Central European', 'Vegetarian Fri...      621     4.0
# ...                                                  ...      ...     ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_id      40000 non-null  object
#  1   city               40000 non-null  object
#  2   Cuisine Style      30717 non-null  object
#  3   Ranking            40000 non-null  int64
#  4   Rating             40000 non-null  float64
#  5   Price              26114 non-null  float64
#  6   Number of Reviews  37457 non-null  float64
#  7   Reviews            40000 non-null  object
#  8   URL_TA             40000 non-null  object
#  9   ID_TA              40000 non-null  object
#  10  city_population    40000 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 3.4+ MB

# %%
df.dropna()
# Out:
#       Restaurant_id    city  \
# 0           id_5569   Paris
# 2            id_352  London
# 4            id_615  Munich
# 6           id_1720   Milan
# 9           id_4209    Rome
# ...             ...     ...
# 39994       id_7074   Paris
# 39995        id_499   Milan
# 39996       id_6340   Paris
# 39998        id_640  Warsaw
# 39999       id_4824   Milan
#
#                                            Cuisine Style  Ranking  Rating  \
# 0                ['European', 'French', 'International']     5570     3.5
# 2      ['Japanese', 'Sushi', 'Asian', 'Grill', 'Veget...      353     4.5
# 4      ['German', 'Central European', 'Vegetarian Fri...      621     4.0
# 6                                   ['Italian', 'Pizza']     1722     4.0
# 9                      ['Italian', 'Pizza', 'Fast Food']     4210     4.0
# ...                                                  ...      ...     ...
# 39994  ['French', 'Fast Food', 'Mediterranean', 'Heal...     7075     4.5
# ...

# %%
df['Price'] = df['Price'].astype('float64')

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)

df = df[['city_population', 'Price','Ranking', 'Number of Reviews', 'Rating']]
df = df.fillna(0)

X = df[['city_population','Price','Ranking', 'Number of Reviews']]
y = df['Rating']
      
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics


regr = RandomForestRegressor(n_estimators=100)  

regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)

print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MAE: 0.212608
